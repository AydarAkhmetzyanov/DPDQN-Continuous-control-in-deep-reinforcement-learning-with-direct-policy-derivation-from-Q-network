# %%
import torch.optim as optim
from ray import tune
from ray.tune import track
from ray.tune.schedulers import ASHAScheduler
from ray.tune.examples.mnist_pytorch import get_data_loaders, ConvNet, train, test

from dpdqn_v2 import DPDQN2
import os
import gym
import numpy as np
import matplotlib.pyplot as plt

from shutil import copyfile
from utils import *
import pickle
import pandas as pd

import datetime

# %%
# test 1 on server

# %%
# %%time
exp_name="server_tune_" + datetime.datetime.now().strftime("%Y_%B_%d_%I_%M%p")

def train_DPDQN(config):
    time_steps = 1e6 #testrun
    envname = "BipedalWalker-v2"
    env = gym.make(envname)
    model = DPDQN2(env, verbose=0, ray_tune=True, 
                  batch_size=config["batch_size"], num_action_samples_final=config["num_action_samples_final"],
                   hidden_size2=config["hidden_size2"], opt_steps_per_step=config["opt_steps_per_step"],
                   gamma=config["gamma"], replay_size=config["replay_size"]
                  )
    model.learn(total_timesteps=int(time_steps))
    

search_space={
    "batch_size": tune.grid_search([16, 32]),
    "num_action_samples_final": tune.grid_search([11, 15, 19]),
    "hidden_size2": tune.grid_search([16, 32]),
    "opt_steps_per_step": tune.grid_search([1, 2]),
    "gamma": tune.grid_search([0.99, 0.995]),
    "replay_size": tune.grid_search([5000, 7500]),
}

analysis = tune.run(
    train_DPDQN,
    name=exp_name,
    config=search_space,
    resources_per_trial={"cpu": 1, "gpu": 0}
)

print("Best config: ", analysis.get_best_config(metric="mean_reward"))

dfs = analysis.trial_dataframes
pickle.dump(dfs, open("tune_results.p", "wb"), pickle.HIGHEST_PROTOCOL)


#tensorboard --logdir ~/ray_results
# Out:
# 2019-11-18 04:02:24,033	INFO resource_spec.py:205 -- Starting Ray with 3.66 GiB memory available for workers and up to 1.84 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2019-11-18 04:02:24,826	INFO function_runner.py:254 -- tune.track signature detected.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.9/16.0 GiB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.8/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 1, 'PENDING': 11})
# PENDING trials:
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	PENDING
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	PENDING
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	PENDING
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	PENDING
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	PENDING
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	PENDING
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	PENDING
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	PENDING
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	PENDING
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	PENDING
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	PENDING
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING
#
# Result for train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_04-02-37
#   done: false
#   experiment_id: ef8b1ad2e0d6438fa527cbceadf74c78
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -99.39984889100901
#   node_ip: 192.168.1.66
#   pid: 55406
#   time_since_restore: 7.091235637664795
#   time_this_iter_s: 7.091235637664795
#   time_total_s: 7.091235637664795
#   timestamp: 1574038957
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153ac0c6
#
# WARNING:tensorflow:From /Users/aydarakhmetzyanov/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/tune/logger.py:223: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.7/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING
#
# Result for train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_04-02-38
#   done: false
#   experiment_id: 0ef86e709afe4263ac0abdac6b93924c
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -111.13721370761397
#   node_ip: 192.168.1.66
#   pid: 55409
#   time_since_restore: 7.381583213806152
#   time_this_iter_s: 7.381583213806152
#   time_total_s: 7.381583213806152
#   timestamp: 1574038958
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153a6840
#
# Result for train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_04-02-38
#   done: false
#   experiment_id: c0b4083bbe124f8cbce6fb5e075fe5fc
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -99.960446890249
#   node_ip: 192.168.1.66
#   pid: 55410
#   time_since_restore: 7.765671968460083
#   time_this_iter_s: 7.765671968460083
#   time_total_s: 7.765671968460083
#   timestamp: 1574038958
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: '15399546'
#
# Result for train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_04-02-38
#   done: false
#   experiment_id: 722ab315039f4cb8bace0efa764e50d8
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -106.31236273235065
#   node_ip: 192.168.1.66
#   pid: 55414
#   time_since_restore: 8.056181907653809
#   time_this_iter_s: 8.056181907653809
#   time_total_s: 8.056181907653809
#   timestamp: 1574038958
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153a060c
#
# Result for train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:
#   date: 2019-11-18_04-02-39
#   done: false
#   experiment_id: e21a20d5ed754df5a517626eca6aedd1
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -108.7229616795566
#   node_ip: 192.168.1.66
#   pid: 55413
#   time_since_restore: 8.372539043426514
#   time_this_iter_s: 8.372539043426514
#   time_total_s: 8.372539043426514
#   timestamp: 1574038959
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153c88f0
#
# Result for train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_04-02-39
#   done: false
#   experiment_id: 80cf9bd310ae43de9d5b47d3c9a177c9
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -106.45008834586702
#   node_ip: 192.168.1.66
#   pid: 55407
#   time_since_restore: 8.970685243606567
#   time_this_iter_s: 8.970685243606567
#   time_total_s: 8.970685243606567
#   timestamp: 1574038959
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153b6c7a
#
# Result for train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_04-02-41
#   done: false
#   experiment_id: cc5550787c3a498998f9800b792c2ad6
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -114.52996686420671
#   node_ip: 192.168.1.66
#   pid: 55411
#   time_since_restore: 10.353580713272095
#   time_this_iter_s: 10.353580713272095
#   time_total_s: 10.353580713272095
#   timestamp: 1574038961
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153bacf0
#
# Result for train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_04-02-43
#   done: false
#   experiment_id: e8e193aaba9d4bfe9497f0f18a1d6999
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -123.2130040303404
#   node_ip: 192.168.1.66
#   pid: 55408
#   time_since_restore: 13.115978956222534
#   time_this_iter_s: 13.115978956222534
#   time_total_s: 13.115978956222534
#   timestamp: 1574038963
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153b0976
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.1/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 7 s, 0 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 7 s, 0 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 13 s, 0 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 10 s, 0 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
# Result for train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_04-03-06
#   done: false
#   experiment_id: 3082360a143b437db21c1c8bfb0b6702
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -114.06306487535944
#   node_ip: 192.168.1.66
#   pid: 55416
#   time_since_restore: 35.26478314399719
#   time_this_iter_s: 35.26478314399719
#   time_total_s: 35.26478314399719
#   timestamp: 1574038986
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153bfd54
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.0/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 7 s, 0 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 7 s, 0 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 13 s, 0 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 10 s, 0 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:
#   date: 2019-11-18_04-03-07
#   done: false
#   experiment_id: cff57bd2b0bc400a9cb55615301ec360
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -110.36429194987664
#   node_ip: 192.168.1.66
#   pid: 55405
#   time_since_restore: 36.16816210746765
#   time_this_iter_s: 36.16816210746765
#   time_total_s: 36.16816210746765
#   timestamp: 1574038987
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 153c4868
#
# Result for train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_04-03-31
#   done: false
#   experiment_id: 9c15448bff3945339c445aef3f1fd23d
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -121.57916461300198
#   node_ip: 192.168.1.66
#   pid: 55412
#   time_since_restore: 60.70054292678833
#   time_this_iter_s: 60.70054292678833
#   time_total_s: 60.70054292678833
#   timestamp: 1574039011
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: '15354368'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.2/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 60 s, 0 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 7 s, 0 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 7 s, 0 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 13 s, 0 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 10 s, 0 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 36 s, 0 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_04-04-01
#   done: false
#   experiment_id: fb76d57b0a2948fdb5732054890993b3
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_reward: -111.04564965907541
#   node_ip: 192.168.1.66
#   pid: 55415
#   time_since_restore: 90.5515398979187
#   time_this_iter_s: 90.5515398979187
#   time_total_s: 90.5515398979187
#   timestamp: 1574039041
#   timesteps_since_restore: 0
#   training_iteration: 0
#   trial_id: 15391fb4
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 60 s, 0 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 7 s, 0 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 7 s, 0 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 13 s, 0 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 10 s, 0 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 36 s, 0 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_04-14-45
#   done: false
#   experiment_id: cc5550787c3a498998f9800b792c2ad6
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -110.31012274757275
#   node_ip: 192.168.1.66
#   pid: 55411
#   time_since_restore: 734.8746240139008
#   time_this_iter_s: 724.5210433006287
#   time_total_s: 734.8746240139008
#   timestamp: 1574039685
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153bacf0
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.8/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 60 s, 0 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 7 s, 0 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 7 s, 0 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 13 s, 0 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 36 s, 0 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
# Result for train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_04-14-47
#   done: false
#   experiment_id: c0b4083bbe124f8cbce6fb5e075fe5fc
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -105.35629097331095
#   node_ip: 192.168.1.66
#   pid: 55410
#   time_since_restore: 736.8602771759033
#   time_this_iter_s: 729.0946052074432
#   time_total_s: 736.8602771759033
#   timestamp: 1574039687
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '15399546'
#
# Result for train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_04-14-48
#   done: false
#   experiment_id: 0ef86e709afe4263ac0abdac6b93924c
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -109.19338276311589
#   node_ip: 192.168.1.66
#   pid: 55409
#   time_since_restore: 738.0922122001648
#   time_this_iter_s: 730.7106289863586
#   time_total_s: 738.0922122001648
#   timestamp: 1574039688
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153a6840
#
# Result for train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_04-15-25
#   done: false
#   experiment_id: e8e193aaba9d4bfe9497f0f18a1d6999
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -96.99043319648935
#   node_ip: 192.168.1.66
#   pid: 55408
#   time_since_restore: 774.3329787254333
#   time_this_iter_s: 761.2169997692108
#   time_total_s: 774.3329787254333
#   timestamp: 1574039725
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153b0976
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.8/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 60 s, 0 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 36 s, 0 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:
#   date: 2019-11-18_04-15-39
#   done: false
#   experiment_id: cff57bd2b0bc400a9cb55615301ec360
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -127.0963784105121
#   node_ip: 192.168.1.66
#   pid: 55405
#   time_since_restore: 788.1118261814117
#   time_this_iter_s: 751.9436640739441
#   time_total_s: 788.1118261814117
#   timestamp: 1574039739
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153c4868
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.7/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 60 s, 0 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_04-15-44
#   done: false
#   experiment_id: 9c15448bff3945339c445aef3f1fd23d
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -119.34479657495649
#   node_ip: 192.168.1.66
#   pid: 55412
#   time_since_restore: 794.2357587814331
#   time_this_iter_s: 733.5352158546448
#   time_total_s: 794.2357587814331
#   timestamp: 1574039744
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '15354368'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 9.7/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 7 s, 0 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
# Result for train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_04-25-49
#   done: false
#   experiment_id: ef8b1ad2e0d6438fa527cbceadf74c78
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -115.52700013384826
#   node_ip: 192.168.1.66
#   pid: 55406
#   time_since_restore: 1398.6813778877258
#   time_this_iter_s: 1391.590142250061
#   time_total_s: 1398.6813778877258
#   timestamp: 1574040349
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153ac0c6
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.2/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 8 s, 0 iter
#
# Result for train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:
#   date: 2019-11-18_04-26-05
#   done: false
#   experiment_id: e21a20d5ed754df5a517626eca6aedd1
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -102.04908865232444
#   node_ip: 192.168.1.66
#   pid: 55413
#   time_since_restore: 1414.7773480415344
#   time_this_iter_s: 1406.404808998108
#   time_total_s: 1414.7773480415344
#   timestamp: 1574040365
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153c88f0
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.1/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 8 s, 0 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 35 s, 0 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
#
# Result for train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_04-26-07
#   done: false
#   experiment_id: 3082360a143b437db21c1c8bfb0b6702
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -117.49797828153828
#   node_ip: 192.168.1.66
#   pid: 55416
#   time_since_restore: 1416.9397208690643
#   time_this_iter_s: 1381.6749377250671
#   time_total_s: 1416.9397208690643
#   timestamp: 1574040367
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153bfd54
#
# Result for train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_04-26-58
#   done: false
#   experiment_id: 722ab315039f4cb8bace0efa764e50d8
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -106.04551527241863
#   node_ip: 192.168.1.66
#   pid: 55414
#   time_since_restore: 1467.742052078247
#   time_this_iter_s: 1459.6858701705933
#   time_total_s: 1467.742052078247
#   timestamp: 1574040418
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153a060c
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 734 s, 1 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
#
# Result for train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_04-27-09
#   done: false
#   experiment_id: cc5550787c3a498998f9800b792c2ad6
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 3
#   mean_reward: -115.31468752059003
#   node_ip: 192.168.1.66
#   pid: 55411
#   time_since_restore: 1478.5289809703827
#   time_this_iter_s: 743.6543569564819
#   time_total_s: 1478.5289809703827
#   timestamp: 1574040429
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 153bacf0
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.3/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 738 s, 1 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 1478 s, 2 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
# Result for train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_04-27-21
#   done: false
#   experiment_id: 0ef86e709afe4263ac0abdac6b93924c
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 3
#   mean_reward: -120.62451715383908
#   node_ip: 192.168.1.66
#   pid: 55409
#   time_since_restore: 1490.4687082767487
#   time_this_iter_s: 752.3764960765839
#   time_total_s: 1490.4687082767487
#   timestamp: 1574040441
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 153a6840
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.2/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 90 s, 0 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 1490 s, 2 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 8 s, 0 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 1478 s, 2 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
#
# Result for train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_04-27-26
#   done: false
#   experiment_id: 80cf9bd310ae43de9d5b47d3c9a177c9
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -76.73975260493357
#   node_ip: 192.168.1.66
#   pid: 55407
#   time_since_restore: 1495.3073740005493
#   time_this_iter_s: 1486.3366887569427
#   time_total_s: 1495.3073740005493
#   timestamp: 1574040446
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153b6c7a
#
# Result for train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_04-27-29
#   done: false
#   experiment_id: fb76d57b0a2948fdb5732054890993b3
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 2
#   mean_reward: -168.0808691809581
#   node_ip: 192.168.1.66
#   pid: 55415
#   time_since_restore: 1498.990464925766
#   time_this_iter_s: 1408.4389250278473
#   time_total_s: 1498.990464925766
#   timestamp: 1574040449
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 15391fb4
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.1/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 1498 s, 1 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 736 s, 1 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 1490 s, 2 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 1495 s, 1 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 1478 s, 2 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
#
# Result for train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_04-27-35
#   done: false
#   experiment_id: c0b4083bbe124f8cbce6fb5e075fe5fc
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 3
#   mean_reward: -136.1682792318987
#   node_ip: 192.168.1.66
#   pid: 55410
#   time_since_restore: 1505.148103237152
#   time_this_iter_s: 768.2878260612488
#   time_total_s: 1505.148103237152
#   timestamp: 1574040455
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '15399546'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.1/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 794 s, 1 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 1498 s, 1 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 1505 s, 2 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 1490 s, 2 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 1495 s, 1 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 1478 s, 2 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
#
# Result for train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_04-28-15
#   done: false
#   experiment_id: 9c15448bff3945339c445aef3f1fd23d
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 3
#   mean_reward: -115.78625608860524
#   node_ip: 192.168.1.66
#   pid: 55412
#   time_since_restore: 1545.2785830497742
#   time_this_iter_s: 751.0428242683411
#   time_total_s: 1545.2785830497742
#   timestamp: 1574040495
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '15354368'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.3/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 1545 s, 2 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 1498 s, 1 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 1505 s, 2 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 1467 s, 1 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 1490 s, 2 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 1398 s, 1 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 774 s, 1 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 1495 s, 1 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 1478 s, 2 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 1416 s, 1 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 788 s, 1 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 1414 s, 1 iter
# Result for train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_04-28-28
#   done: false
#   experiment_id: e8e193aaba9d4bfe9497f0f18a1d6999
#   hostname: Aydars-MacBook-Pro.local
# ...
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 19380 s, 27 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 18702 s, 14 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 18682 s, 14 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
#
# Result for train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:
#   date: 2019-11-18_09-35-30
#   done: false
#   experiment_id: c0b4083bbe124f8cbce6fb5e075fe5fc
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 29
#   mean_reward: -107.79649191729426
#   node_ip: 192.168.1.66
#   pid: 55410
#   time_since_restore: 19980.110255241394
#   time_this_iter_s: 700.4544460773468
#   time_total_s: 19980.110255241394
#   timestamp: 1574058930
#   timesteps_since_restore: 0
#   training_iteration: 28
#   trial_id: '15399546'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.3/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 19287 s, 27 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 19875 s, 15 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 19980 s, 28 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 19851 s, 15 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 19380 s, 27 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 18702 s, 14 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 18682 s, 14 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
# Result for train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:
#   date: 2019-11-18_09-35-57
#   done: false
#   experiment_id: 9c15448bff3945339c445aef3f1fd23d
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 29
#   mean_reward: -55.73752764215061
#   node_ip: 192.168.1.66
#   pid: 55412
#   time_since_restore: 20006.430218935013
#   time_this_iter_s: 718.4626898765564
#   time_total_s: 20006.430218935013
#   timestamp: 1574058957
#   timesteps_since_restore: 0
#   training_iteration: 28
#   trial_id: '15354368'
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 20006 s, 28 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 19875 s, 15 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 19980 s, 28 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 19851 s, 15 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 19380 s, 27 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 18702 s, 14 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 18682 s, 14 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
#
# Result for train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:
#   date: 2019-11-18_09-36-08
#   done: false
#   experiment_id: 3082360a143b437db21c1c8bfb0b6702
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 16
#   mean_reward: -80.17568216562299
#   node_ip: 192.168.1.66
#   pid: 55416
#   time_since_restore: 20017.724562883377
#   time_this_iter_s: 1334.7659709453583
#   time_total_s: 20017.724562883377
#   timestamp: 1574058968
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: 153bfd54
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 20006 s, 28 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 19875 s, 15 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 19980 s, 28 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 19851 s, 15 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 19380 s, 27 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 18702 s, 14 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 20017 s, 15 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
#
# Result for train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:
#   date: 2019-11-18_09-36-20
#   done: false
#   experiment_id: 80cf9bd310ae43de9d5b47d3c9a177c9
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 16
#   mean_reward: -98.40154422384012
#   node_ip: 192.168.1.66
#   pid: 55407
#   time_since_restore: 20029.634365081787
#   time_this_iter_s: 1327.3095269203186
#   time_total_s: 20029.634365081787
#   timestamp: 1574058980
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: 153b6c7a
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 20006 s, 28 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 19875 s, 15 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 19980 s, 28 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 19851 s, 15 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 19380 s, 27 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 20029 s, 15 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 20017 s, 15 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
#
# Result for train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:
#   date: 2019-11-18_09-38-23
#   done: false
#   experiment_id: 0ef86e709afe4263ac0abdac6b93924c
#   hostname: Aydars-MacBook-Pro.local
#   iterations_since_restore: 29
#   mean_reward: -76.01123276713764
#   node_ip: 192.168.1.66
#   pid: 55409
#   time_since_restore: 20153.03570508957
#   time_this_iter_s: 772.9092600345612
#   time_total_s: 20153.03570508957
#   timestamp: 1574059103
#   timesteps_since_restore: 0
#   training_iteration: 28
#   trial_id: 153a6840
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 12/12 CPUs, 0/0 GPUs, 0.0/3.66 GiB heap, 0.0/1.22 GiB objects
# Memory usage on this node: 10.4/16.0 GiB
# Result logdir: /Users/aydarakhmetzyanov/ray_results/server_tune_2019_November_18_04_02AM
# Number of trials: 12 ({'RUNNING': 12})
# RUNNING trials:
#  - train_DPDQN_0_batch_size=16,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55412], 20006 s, 28 iter
#  - train_DPDQN_1_batch_size=32,hidden_size2=16,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55415], 19875 s, 15 iter
#  - train_DPDQN_2_batch_size=16,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55410], 19980 s, 28 iter
#  - train_DPDQN_3_batch_size=32,hidden_size2=32,num_action_samples_final=11:	RUNNING, [1 CPUs, 0 GPUs], [pid=55414], 19851 s, 15 iter
#  - train_DPDQN_4_batch_size=16,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55409], 20153 s, 28 iter
#  - train_DPDQN_5_batch_size=32,hidden_size2=16,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55406], 19925 s, 15 iter
#  - train_DPDQN_6_batch_size=16,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55408], 19586 s, 27 iter
#  - train_DPDQN_7_batch_size=32,hidden_size2=32,num_action_samples_final=13:	RUNNING, [1 CPUs, 0 GPUs], [pid=55407], 20029 s, 15 iter
#  - train_DPDQN_8_batch_size=16,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55411], 19731 s, 27 iter
#  - train_DPDQN_9_batch_size=32,hidden_size2=16,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55416], 20017 s, 15 iter
#  - train_DPDQN_10_batch_size=16,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55405], 19544 s, 27 iter
#  - train_DPDQN_11_batch_size=32,hidden_size2=32,num_action_samples_final=16:	RUNNING, [1 CPUs, 0 GPUs], [pid=55413], 19843 s, 15 iter
# ---------------------------------------------------------------------------
# RayletError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     244     last_debug = 0
#     245     while not runner.is_finished():
# --> 246         runner.step()
#     247         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     248             if verbose:
#
# ~/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     334                 self.trial_executor.start_trial(next_trial)
#     335         elif self.trial_executor.get_running_trials():
# --> 336             self._process_events()  # blocking
#     337         else:
#     338             for trial in self._trials:
#
# ~/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     507                                                        failed_trial.node_ip))
#     508         else:
# --> 509             trial = self.trial_executor.get_next_available_trial()  # blocking
#     510             with warn_if_slow("process_trial"):
#     511                 self._process_trial(trial)
#
# ~/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     325         # See https://github.com/ray-project/ray/issues/4211 for details.
#     326         start = time.time()
# --> 327         [result_id], _ = ray.wait(shuffled_results)
#     328         wait_time = time.time() - start
#     329         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda3/envs/qlearning/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2271             num_returns,
#    2272             timeout_milliseconds,
# -> 2273             worker.current_task_id,
#    2274         )
#    2275         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.

# %%
#dfs=pickle.load(open("tune_results.p", "rb"))
ax = None  # This plots everything on the same plot
for d in dfs.values():
    ax = d.mean_accuracy.plot(ax=ax, legend=False)
    
#tensorboard --logdir ~/ray_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-124b09e9acd1> in <module>
#       1 #dfs=pickle.load(open("tune_results.p", "rb"))
#       2 ax = None  # This plots everything on the same plot
# ----> 3 for d in dfs.values():
#       4     ax = d.mean_accuracy.plot(ax=ax, legend=False)
#       5
#
# NameError: name 'dfs' is not defined

# %%
#tensorboard  --host 0.0.0.0 —port 6006 --logdir ~/ray_results/server_tune_2019_November_14_10_10PM
